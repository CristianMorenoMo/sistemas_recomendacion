# %%
import pandas as pd
import numpy as np
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import KNNBasic
from surprise import accuracy
from random import sample
import joblib
import seaborn as sns
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
# %reload_ext sql
# %sql postgresql://studentrs:szcWuiyxVnKO38XfzHkP@workshop1rs.cevhjouwoh1r.us-east-2.rds.amazonaws.com/workshop_1
engine = create_engine("postgresql://studentrs:szcWuiyxVnKO38XfzHkP@workshop1rs.cevhjouwoh1r.us-east-2.rds.amazonaws.com/workshop_1")

# %%
modelo = joblib.load('modelo_entrenado/recomender_model_colaborative.sav')
modelo

# %%
data_to_predict = joblib.load('modelo_entrenado/user_predict.joblib')
data_to_predict
# Out:
# [(1, '000d90ec-d64c-48a1-b775-e726fd240e9f', 0.055594916168782635),
#  (1, '0039c7ae-e1a7-4a7d-9b49-0cbc716821a6', 0.055594916168782635),
#  (1, '0053dbd9-bfbc-4e38-9f08-66a27d914c38', 0.055594916168782635),
#  (1, '006f0783-c5a0-458b-a9da-f8551f7ebe77', 0.055594916168782635),
#  (1, '0103c1cc-4a09-4a5d-a344-56ad99a77193', 0.055594916168782635),
#  (1, '0110e63e-0a9b-4818-af8e-41e180c20b9a', 0.055594916168782635),
#  (1, '01252145-c9e8-4de5-a480-9b2bed05450a', 0.055594916168782635),
#  (1, '013fa897-86db-41d3-8e9f-386c8a34f4e6', 0.055594916168782635),
#  (1, '0162d4d9-c625-499d-bdbb-846462f4e0d4', 0.055594916168782635),
#  (1, '01809552-4f87-45b0-afff-2c6f0730a3be', 0.055594916168782635),
#  (1, '01c5b492-6002-4780-a2c8-4edc7564ada1', 0.055594916168782635),
#  (1, '01d3c51b-9b98-418a-8d8e-37f6fab59d8c', 0.055594916168782635),
#  (1, '02031e5c-f9ab-4b4e-bc08-a61ea11a455d', 0.055594916168782635),
#  (1, '020bfbb4-05c3-4c86-b372-17825c262094', 0.055594916168782635),
# ...

# %%
[data_to_predict[i] for i in range(len(data_to_predict)) if data_to_predict[i][0] == 1]
# Out:
# [(1, '000d90ec-d64c-48a1-b775-e726fd240e9f', 0.055594916168782635),
#  (1, '0039c7ae-e1a7-4a7d-9b49-0cbc716821a6', 0.055594916168782635),
#  (1, '0053dbd9-bfbc-4e38-9f08-66a27d914c38', 0.055594916168782635),
#  (1, '006f0783-c5a0-458b-a9da-f8551f7ebe77', 0.055594916168782635),
#  (1, '0103c1cc-4a09-4a5d-a344-56ad99a77193', 0.055594916168782635),
#  (1, '0110e63e-0a9b-4818-af8e-41e180c20b9a', 0.055594916168782635),
#  (1, '01252145-c9e8-4de5-a480-9b2bed05450a', 0.055594916168782635),
#  (1, '013fa897-86db-41d3-8e9f-386c8a34f4e6', 0.055594916168782635),
#  (1, '0162d4d9-c625-499d-bdbb-846462f4e0d4', 0.055594916168782635),
#  (1, '01809552-4f87-45b0-afff-2c6f0730a3be', 0.055594916168782635),
#  (1, '01c5b492-6002-4780-a2c8-4edc7564ada1', 0.055594916168782635),
#  (1, '01d3c51b-9b98-418a-8d8e-37f6fab59d8c', 0.055594916168782635),
#  (1, '02031e5c-f9ab-4b4e-bc08-a61ea11a455d', 0.055594916168782635),
#  (1, '020bfbb4-05c3-4c86-b372-17825c262094', 0.055594916168782635),
# ...

# %%
a = modelo.test([data_to_predict[i] for i in range(len(data_to_predict)) if data_to_predict[i][0] == 1])

# %%
y = pd.DataFrame(a).sort_values('est', ascending = False)[['uid','iid','est']].head(20).reset_index().drop('index', axis = 1)[['est','iid','uid']].reset_index().rename(columns = {'index':'id','est':'rating','iid':'artist_id','uid':'user_id'})
y
# Out:
#     id    rating                             artist_id  user_id
# 0    0  0.234750  13991835-5e66-4fdd-aad3-211e8129c599        1
# 1    1  0.233597  d7f473aa-ab4e-405f-bc90-c35fc30bbbe1        1
# 2    2  0.217570  86aa8b2d-be7e-489c-a1b7-80e814fb6815        1
# 3    3  0.211264  574a5acd-3e0a-418b-9a8e-fb260be389bf        1
# 4    4  0.210530  50fc4742-1389-45a0-8c6f-6a5159ae20c2        1
# 5    5  0.209672  9cb53b2c-c2db-48db-9644-d21600f7b552        1
# 6    6  0.200906  75f4b30f-cae2-4812-9953-2e6969a16934        1
# 7    7  0.200122  6dad335e-95d6-4d51-b024-822914d83085        1
# 8    8  0.196198  5201f3ff-3be2-4667-96c0-e325b8cedbc5        1
# 9    9  0.193817  fbeaf468-bc8d-40eb-a530-4f8982b2e1fe        1
# 10  10  0.193511  7acc6c97-2654-4ffa-945f-daeabaa8e5ae        1
# 11  11  0.189103  ebe18ea1-9fcf-426e-9c54-10eecc207a66        1
# 12  12  0.189042  2eabaae4-ab68-4d60-bdc2-a2d1d2abc092        1
# 13  13  0.188611  27672880-726b-423d-8456-72b8f404710f        1
# ...

# %%
# %%time
user_list = pd.DataFrame(data_to_predict, columns = ['idusuario','iditem','fill'])['idusuario'].unique()
testing = pd.DataFrame()
k = 0
for user in user_list:
    temp = pd.DataFrame(modelo.test([data_to_predict[i] for i in range(len(data_to_predict)) if data_to_predict[i][0] == user]))
    temp = temp.sort_values('est', ascending = False)[['uid','iid','est']].head(20).reset_index().drop('index', axis = 1)[['est','iid','uid']].reset_index().rename(columns = {'index':'id','est':'rating','iid':'artist_id','uid':'user_id'})
    temp.id = temp.id + k
    temp.to_sql('items_ratings', con = engine, if_exists = 'append', index = False)
    k += 20
# Out:
# Wall time: 5h 10min 59s
